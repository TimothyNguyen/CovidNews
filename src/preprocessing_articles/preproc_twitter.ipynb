# %%
# !pip install GetOldTweets3

# %%
from pandas import DataFrame, read_csv
import pandas as pd 
twitter_url_reps = r'../legislators-current.csv'
pd.set_option('mode.chained_assignment', None)
df = pd.read_csv(twitter_url_reps)

# %%
df.head()
# Out:
#   last_name first_name middle_name suffix nickname             full_name  \
# 0     Brown    Sherrod         NaN    NaN      NaN         Sherrod Brown
# 1  Cantwell      Maria         NaN    NaN      NaN        Maria Cantwell
# 2    Cardin   Benjamin          L.    NaN      NaN    Benjamin L. Cardin
# 3    Carper     Thomas     Richard    NaN      NaN      Thomas R. Carper
# 4     Casey     Robert          P.    Jr.      Bob  Robert P. Casey, Jr.
#
#      birthday gender type state  ...  opensecrets_id  lis_id  \
# 0  1952-11-09      M  sen    OH  ...       N00003535    S307
# 1  1958-10-13      F  sen    WA  ...       N00007836    S275
# 2  1943-10-05      M  sen    MD  ...       N00001955    S308
# 3  1947-01-23      M  sen    DE  ...       N00012508    S277
# 4  1960-04-13      M  sen    PA  ...       N00027503    S309
#
#                fec_ids cspan_id govtrack_id votesmart_id  ballotpedia_id  \
# 0  H2OH13033,S6OH00163   5051.0      400050      27018.0   Sherrod Brown
# ...

# %%
new = df[['full_name', 'twitter', 'party', 'type', 'gender', 'state', 'district']]
new.rename(columns={'full_name': 'name', 'type': 'title', 'state': 'area_id'}, inplace=True)
new.head(5)
# Out:
#                    name          twitter     party title gender area_id  \
# 0         Sherrod Brown  SenSherrodBrown  Democrat   sen      M      OH
# 1        Maria Cantwell  SenatorCantwell  Democrat   sen      F      WA
# 2    Benjamin L. Cardin    SenatorCardin  Democrat   sen      M      MD
# 3      Thomas R. Carper    SenatorCarper  Democrat   sen      M      DE
# 4  Robert P. Casey, Jr.      SenBobCasey  Democrat   sen      M      PA
#
#    district
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN

# %%
new.loc[new['area_id'].str.contains('AL'), 'area_id'] = 'alabama'
new.loc[new['area_id'].str.contains('AK'), 'area_id'] = 'alaska'
new.loc[new['area_id'].str.contains('AR'), 'area_id'] = 'arkansas'
new.loc[new['area_id'].str.contains('AZ'), 'area_id'] = 'arizona'
new.loc[new['area_id'].str.contains('CA'), 'area_id'] = 'california'
new.loc[new['area_id'].str.contains('CO'), 'area_id'] = 'colorado'
new.loc[new['area_id'].str.contains('CT'), 'area_id'] = 'connecticut'
new.loc[new['area_id'].str.contains('DE'), 'area_id'] = 'delaware'
new.loc[new['area_id'].str.contains('FL'), 'area_id'] = 'florida'
new.loc[new['area_id'].str.contains('GA'), 'area_id'] = 'georgia'
new.loc[new['area_id'].str.contains('HI'), 'area_id'] = 'hawaii'
new.loc[new['area_id'].str.contains('ID'), 'area_id'] = 'idaho'
new.loc[new['area_id'].str.contains('IL'), 'area_id'] = 'illinois'
new.loc[new['area_id'].str.contains('IN'), 'area_id'] = 'indiana'
new.loc[new['area_id'].str.contains('IA'), 'area_id'] = 'iowa'
new.loc[new['area_id'].str.contains('KS'), 'area_id'] = 'kansas'
new.loc[new['area_id'].str.contains('KY'), 'area_id'] = 'kentucky'
new.loc[new['area_id'].str.contains('LA'), 'area_id'] = 'louisiana'
new.loc[new['area_id'].str.contains('ME'), 'area_id'] = 'maine'
new.loc[new['area_id'].str.contains('MD'), 'area_id'] = 'maryland'
new.loc[new['area_id'].str.contains('MA'), 'area_id'] = 'massachusetts'
new.loc[new['area_id'].str.contains('MI'), 'area_id'] = 'michigan'
new.loc[new['area_id'].str.contains('MN'), 'area_id'] = 'minnesota'
new.loc[new['area_id'].str.contains('MS'), 'area_id'] = 'mississippi'
new.loc[new['area_id'].str.contains('MO'), 'area_id'] = 'missouri'
new.loc[new['area_id'].str.contains('MT'), 'area_id'] = 'montana'
new.loc[new['area_id'].str.contains('NE'), 'area_id'] = 'nebraska'
new.loc[new['area_id'].str.contains('NV'), 'area_id'] = 'nevada'
new.loc[new['area_id'].str.contains('NH'), 'area_id'] = 'new hampshire'
new.loc[new['area_id'].str.contains('NJ'), 'area_id'] = 'new jersey'
new.loc[new['area_id'].str.contains('NM'), 'area_id'] = 'new mexico'
new.loc[new['area_id'].str.contains('NY'), 'area_id'] = 'new york'
new.loc[new['area_id'].str.contains('NC'), 'area_id'] = 'north carolina'
new.loc[new['area_id'].str.contains('ND'), 'area_id'] = 'north dakota'
new.loc[new['area_id'].str.contains('OH'), 'area_id'] = 'ohio'
new.loc[new['area_id'].str.contains('OK'), 'area_id'] = 'oklahoma'
new.loc[new['area_id'].str.contains('OR'), 'area_id'] = 'oregon'
new.loc[new['area_id'].str.contains('PA'), 'area_id'] = 'pennsylvania'
new.loc[new['area_id'].str.contains('RI'), 'area_id'] = 'rhode island'
new.loc[new['area_id'].str.contains('SC'), 'area_id'] = 'south carolina'
new.loc[new['area_id'].str.contains('SD'), 'area_id'] = 'south dakota'
new.loc[new['area_id'].str.contains('TN'), 'area_id'] = 'tennessee'
new.loc[new['area_id'].str.contains('TX'), 'area_id'] = 'texas'
new.loc[new['area_id'].str.contains('UT'), 'area_id'] = 'utah'
new.loc[new['area_id'].str.contains('VA'), 'area_id'] = 'vermont'
new.loc[new['area_id'].str.contains('VA'), 'area_id'] = 'virginia'
new.loc[new['area_id'].str.contains('WA'), 'area_id'] = 'washington'
new.loc[new['area_id'].str.contains('WV'), 'area_id'] = 'west virginia'
new.loc[new['area_id'].str.contains('WI'), 'area_id'] = 'wisconsin'
new.loc[new['area_id'].str.contains('WY'), 'area_id'] = 'Wyoming'
new.rename(columns={'area_id': 'state'}, inplace=True)
new.head(5)
# Out:
#                    name          twitter     party title gender         state  \
# 0         Sherrod Brown  SenSherrodBrown  Democrat   sen      M          ohio
# 1        Maria Cantwell  SenatorCantwell  Democrat   sen      F    washington
# 2    Benjamin L. Cardin    SenatorCardin  Democrat   sen      M      maryland
# 3      Thomas R. Carper    SenatorCarper  Democrat   sen      M      delaware
# 4  Robert P. Casey, Jr.      SenBobCasey  Democrat   sen      M  pennsylvania
#
#    district
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN

# %%
# twitter_url_senate = r'../us-senate.csv'
# df2 = pd.read_csv(twitter_url_senate)

# %%
# new2 = df2[['name', 'twitter_handle', 'party', 'title', 'gender', 'state_name_slug']]
# new2.rename(columns={'twitter_handle': 'twitter', 'state_name_slug': 'state'}, inplace=True)
# new2.head(5)

# %%
# new = new.merge(new2, how='outer')
new.head()
# Out:
#                    name          twitter     party title gender         state  \
# 0         Sherrod Brown  SenSherrodBrown  Democrat   sen      M          ohio
# 1        Maria Cantwell  SenatorCantwell  Democrat   sen      F    washington
# 2    Benjamin L. Cardin    SenatorCardin  Democrat   sen      M      maryland
# 3      Thomas R. Carper    SenatorCarper  Democrat   sen      M      delaware
# 4  Robert P. Casey, Jr.      SenBobCasey  Democrat   sen      M  pennsylvania
#
#    district
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN

# %%
len(new)
# Out:
# 537

# %%
new.loc[new['title'] == 'sen', 'title'] = 'senator'
new.loc[new['title'] == 'rep', 'title'] = 'house of representatives'
new.head()
# Out:
#                    name          twitter     party    title gender  \
# 0         Sherrod Brown  SenSherrodBrown  Democrat  senator      M
# 1        Maria Cantwell  SenatorCantwell  Democrat  senator      F
# 2    Benjamin L. Cardin    SenatorCardin  Democrat  senator      M
# 3      Thomas R. Carper    SenatorCarper  Democrat  senator      M
# 4  Robert P. Casey, Jr.      SenBobCasey  Democrat  senator      M
#
#           state  district
# 0          ohio       NaN
# 1    washington       NaN
# 2      maryland       NaN
# 3      delaware       NaN
# 4  pennsylvania       NaN

# %%
print(len(new.loc[new['title'] == 'senator']))
print(len(new.loc[new['title'] == 'house of representatives']))
# Out:
# 100
# 437

# %%
new.to_csv('reps.csv', encoding='utf-8')

# %%
import GetOldTweets3 as got
tweetCriteria = got.manager.TweetCriteria().setUsername("barackobama whitehouse")\
                                           .setMaxTweets(2)
tweet = got.manager.TweetManager.getTweets(tweetCriteria)[0]
print(tweet.text)
# Out:
# Four years ago, @MichelleObama and I had the privilege to host Lt. Cmdr. Dan Cnossen and his fellow Paralympians and Olympians at the White House. Today, we’re so proud of him for winning gold and silver - while still representing the red, white, and blue.

# %%
tweetTrump =  got.manager.TweetCriteria().setUsername("realDonaldTrump")\
                                           .setSince("2019-12-25")\
                                           .setUntil("2020-06-19")\
                                           .setQuerySearch('coronavirus')
tweet2 = got.manager.TweetManager.getTweets(tweetTrump)
#for tw in tweet2:
#    print(tw.text, "\n")

# %%
tweetTrump =  got.manager.TweetCriteria().setUsername("realDonaldTrump")\
                                           .setSince("2019-12-25")\
                                           .setUntil("2020-06-19")\
                                           .setQuerySearch('covid')
tweet2 = got.manager.TweetManager.getTweets(tweetTrump)
#for tw in tweet2:
#    print(tw.text, "\n")

# %%
tweetTrump =  got.manager.TweetCriteria().setUsername("realDonaldTrump")\
                                           .setSince("2019-12-25")\
                                           .setUntil("2020-06-19")\
                                           .setQuerySearch('virus')
tweet2 = got.manager.TweetManager.getTweets(tweetTrump)
#for tw in tweet2:
#    print(tw.text, "\n")

# %%
tweetTrump =  got.manager.TweetCriteria().setUsername("realDonaldTrump")\
                                            .setSince("2019-12-25")\
                                            .setUntil("2020-06-20")\
                                            .setQuerySearch('virus')
tweetTrump2 =  got.manager.TweetCriteria().setUsername("realDonaldTrump")\
                                            .setSince("2019-12-25")\
                                            .setUntil("2020-06-20")\
                                            .setQuerySearch('coronavirus')
tweetTrump3 =  got.manager.TweetCriteria().setUsername("realDonaldTrump")\
                                            .setSince("2019-12-25")\
                                            .setUntil("2020-06-20")\
                                            .setQuerySearch('covid')
tweetTrump4 =  got.manager.TweetCriteria().setUsername("realDonaldTrump")\
                                            .setSince("2019-12-25")\
                                            .setUntil("2020-06-20")\
                                            .setQuerySearch('covid-19')
tweetTrump5 =  got.manager.TweetCriteria().setUsername("realDonaldTrump")\
                                            .setSince("2019-12-25")\
                                            .setUntil("2020-06-20")\
                                            .setQuerySearch('lockdown')
tweetTrump6 =  got.manager.TweetCriteria().setUsername("realDonaldTrump")\
                                            .setSince("2019-12-25")\
                                            .setUntil("2020-06-20")\
                                            .setQuerySearch('shutdown')
tweetTrump7 =  got.manager.TweetCriteria().setUsername("realDonaldTrump")\
                                            .setSince("2019-12-25")\
                                            .setUntil("2020-06-20")\
                                            .setQuerySearch('hydroxychloroquine')
tweetTrump8 =  got.manager.TweetCriteria().setUsername("realDonaldTrump")\
                                            .setSince("2019-12-25")\
                                            .setUntil("2020-06-20")\
                                            .setQuerySearch('fauci')
tweetTrump9 =  got.manager.TweetCriteria().setUsername("realDonaldTrump")\
                                            .setSince("2019-12-25")\
                                            .setUntil("2020-06-20")\
                                            .setQuerySearch('pandemic')
tweet2 = got.manager.TweetManager.getTweets(tweetTrump9)
for tw in tweet2:
    print(tw.text, "\n")

# %%
tweetTrump =  got.manager.TweetCriteria().setUsername("realDonaldTrump")\
                                            .setSince("2019-12-25")\
                                            .setUntil("2020-06-20")\
                                            .setQuerySearch('virus')
tweetTrump2 =  got.manager.TweetCriteria().setUsername("realDonaldTrump")\
                                            .setSince("2019-12-25")\
                                            .setUntil("2020-06-20")\
                                            .setQuerySearch('coronavirus')
tweetTrump3 =  got.manager.TweetCriteria().setUsername("realDonaldTrump")\
                                            .setSince("2019-12-25")\
                                            .setUntil("2020-06-20")\
                                            .setQuerySearch('covid')
tweetTrump4 =  got.manager.TweetCriteria().setUsername("realDonaldTrump")\
                                            .setSince("2019-12-25")\
                                            .setUntil("2020-06-20")\
                                            .setQuerySearch('covid-19')
tweetTrump5 =  got.manager.TweetCriteria().setUsername("realDonaldTrump")\
                                            .setSince("2019-12-25")\
                                            .setUntil("2020-06-20")\
                                            .setQuerySearch('lockdown')
tweetTrump6 =  got.manager.TweetCriteria().setUsername("realDonaldTrump")\
                                            .setSince("2019-12-25")\
                                            .setUntil("2020-06-20")\
                                            .setQuerySearch('shutdown')
tweetTrump7 =  got.manager.TweetCriteria().setUsername("realDonaldTrump")\
                                            .setSince("2019-12-25")\
                                            .setUntil("2020-06-20")\
                                            .setQuerySearch('hydroxychloroquine')
tweetTrump8 =  got.manager.TweetCriteria().setUsername("realDonaldTrump")\
                                            .setSince("2019-12-25")\
                                            .setUntil("2020-06-20")\
                                            .setQuerySearch('fauci')
tweetTrump9 =  got.manager.TweetCriteria().setUsername("realDonaldTrump")\
                                            .setSince("2019-12-25")\
                                            .setUntil("2020-06-20")\
                                            .setQuerySearch('pandemic')
tweet2 = got.manager.TweetManager.getTweets(tweetTrump9)
for tw in tweet2:
    print(tw.text, "\n")
# Out:
# We have just reached a very sad milestone with the coronavirus pandemic deaths reaching 100,000. To all of the families &amp; friends of those who have passed, I want to extend my heartfelt sympathy &amp; love for everything that these great people stood for &amp; represent. God be with you!
#
# I am proud to announce that the United States will donate ventilators to our friends in India. We stand with India and @narendramodi during this pandemic. We’re also cooperating on vaccine development. Together we will beat the invisible enemy!
#
# .@CBS and their show, @60Minutes, are doing everything within their power, which is far less today than it was in the past, to defend China and the horrible Virus pandemic that was inflicted on the USA and the rest of the World. I guess they want to do business in China!
#
# ...
